# %%
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession

# %%
#Truy cập vào master của cụm tại địa chỉ 172.19.0.4:7077 với tên chương trình là Stock_price_analysis
spark = SparkSession.builder.master("spark://172.20.0.8:7077").appName("Gold").getOrCreate()

# %%
csvFile = spark.read.format("csv")\
.option("header", "true")\
.option("inferSchema", "true")\
.load("hdfs://namenode:9000/gold/gold.csv")

# %%
csvFile.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- US_dollar: string (nullable = true)
#  |-- Euro: string (nullable = true)
#  |-- Japanese_yen: string (nullable = true)
#  |-- Vietnamese_dong: string (nullable = true)
#  |-- Korean_won: string (nullable = true)

# %%
csvFile=csvFile.replace('#N/A','0').replace(',','')
# df = csvFile.toPandas()
# df["US_dollar"]=df["US_dollar"].replace(',','', regex=True).astype(float)
# df["Euro"]=df["Euro"].replace(',','', regex=True).astype(float)
# df["Japanese_yen"]=df["Japanese_yen"].replace('#N/A','0', regex=True).replace(',','', regex=True).astype(float)
# df["Vietnamese_dong"]=df["Vietnamese_dong"].replace('#N/A','0', regex=True).replace(',','', regex=True).astype(float)
# df["Korean_won"]=df["Korean_won"].replace('#N/A','0', regex=True).replace(',','', regex=True).astype(float)

# %%
from pyspark.sql.functions import *

csvFile = csvFile.withColumn('Korean_won', regexp_replace('Korean_won', ',', ''))

# %%
csvFile.show()
# df.head()
# Out:
# +----------+---------+-----+------------+---------------+----------+-----------+
# |      Name|US_dollar| Euro|Japanese_yen|Vietnamese_dong|Korean_won|Korean_won1|
# +----------+---------+-----+------------+---------------+----------+-----------+
# |12/29/1978|      226|137.1|           0|              0|         0|          0|
# |  1/1/1979|      226|137.1|           0|              0|         0|          0|
# |  1/2/1979|    226.8|137.3|   43,164.90|              0| 107470.00|  107470.00|
# |  1/3/1979|    218.6|  134|   43,717.90|              0| 108027.40|  108027.40|
# |  1/4/1979|    223.2|136.8|   43,674.90|              0| 108602.50|  108602.50|
# |  1/5/1979|    225.5|138.4|   44,582.50|              0| 110510.40|  110510.40|
# |  1/8/1979|    223.1|136.4|   44,436.20|              0| 110356.30|  110356.30|
# |  1/9/1979|      224|137.3|   44,045.60|              0| 109248.40|  109248.40|
# | 1/10/1979|    220.7|135.5|   43,366.40|              0| 108108.30|  108108.30|
# ...

# %%
import matplotlib.pyplot as plt

df.plot(x='Name', y= 'US_dollar', label='gold', figsize=(16,6))
plt.ylabel('Gía vàng (USD)')
plt.xlabel('Thời gian')
plt.title('Gía vàng tại Mỹ')
# Out:
# Text(0.5, 1.0, 'Gía vàng tại Mỹ')

# %%
df[["US_dollar", "Euro"]].plot(figsize=(20,6))
# Out:
# <AxesSubplot:>

# %%
ax = df.plot(x='Name', y= 'US_dollar', label='USD', figsize=(16,6))
ax = df.plot(ax=ax, x= 'Name', y= 'Euro',label='Euro')
